# %%
import launcher
l=launcher.Launcher()

# %% [markdown]
# The basics needed to get the model running in the notebook. Assumes the notebook is running in the same folder as launcher.py

# %%
l.set_angles(8,-90)

# %% [markdown]
# Gives the model an exit velocity of 8ms<sup>-1</sup>, -90 is irrelevant for now

# %%
l.plot_angle_v_range()

# %%
l.set_angles(8,45)

# %%
l.get_range() - l.get_range_drag()
# Out:
# 0.07131731655200113

# %% [markdown]
# shows how much difference drag will make at this distance, assuming a C<sub>d</sub> of 1 (very high)

# %%
l.get_time_of_flight()
# Out:
# 1.3878141072931596

# %% [markdown]
# shows how long the ball will be in the air for the given settings
